# %% [markdown]
# Ex. 1
# Data visualization matters because it helps people understand complex information quickly and spot trends or patterns. The functions of data visualization are : Clarity and Understanding , Pattern Identification,Communication and Storytelling.
# Line graphs specifically show how things change over time, making it easy to see trends, relationships between variables, and any unusual occurrences. They're great for visualizing data that evolves over a continuous scale, like time. The primary purposes of a line graph include:Visualizing Trends,Highlighting Relationships,Identifying Patterns and Anomalies.

# %% [markdown]
# Ex.2

# %%
import matplotlib.pyplot as plt
temperature_values = [72, 74, 76, 80, 82, 78, 75]
days_of_week = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
plt.plot(days_of_week, temperature_values, marker='o', linestyle='-')

plt.xlabel('Day')
plt.ylabel('Temperature (°F)')
plt.title('Temperature Variations Over a Week')

plt.show()

# %% [markdown]
# Ex.3

# %%
sales_values = [5000, 5500, 6200, 7000, 7500]
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May']
plt.bar(months, sales_values, color='purple')

plt.xlabel('Month')
plt.ylabel('Sales Amount ($)')
plt.title('Monthly Sales Data')

plt.show()

# %% [markdown]
# Ex. 4

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv(r'/content/sales_data.csv')
df.head()
# Out:
#          date     product     category   price  quantity  revenue
# 0  2022-01-01  Smartphone  Electronics   600.0      10.0   6000.0
# 1  2022-01-01      Laptop  Electronics  1200.0       5.0   6000.0
# 2  2022-01-02     T-Shirt     Clothing    20.0      50.0   1000.0
# 3  2022-01-03  Headphones  Electronics   100.0      20.0   2000.0
# 4  2022-01-04     T-Shirt     Clothing    20.0      25.0    500.0

# %%
df['quantity'].sum() #the total quantity of products sold by the company.
# Out:
# 5360.0

# %%
category_revenue = df.groupby('category')['revenue'].sum()
category_highest_revenue = category_revenue.idxmax()
highest_revenue = category_revenue.max()

print(f'Catagories are: {category_revenue}')
print(f'Catagory highest revenue is: {category_highest_revenue}')
print(f'It generates revenue : {highest_revenue}')
# Out:
# Catagories are: category
# Accessories    104700.0
# Bags            19500.0
# Bgas              900.0
# Clohting         1200.0
# Clothing        94350.0
# Electronics    516080.0
# Shoes           20640.0
# Shoeses           960.0
# Name: revenue, dtype: float64
# Catagory highest revenue is: Electronics
# It generates revenue : 516080.0

# %%
average_revenue_per_sale = df['revenue'].mean()
print(average_revenue_per_sale)
# Out:
# 2060.679347826087

# %%
df['date'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      2022-01-01
# 1      2022-01-01
# 2      2022-01-02
# 3      2022-01-03
# 4      2022-01-04
#           ...
# 364    2022-12-27
# 365    2022-12-28
# 366    2022-12-29
# 367    2022-12-30
# 368    2022-12-31
# Name: date, Length: 369, dtype: object>

# %%
df['date'] = pd.to_datetime(df['date'])  # Convert 'date' column to datetime format
df['quarter'] = df['date'].dt.to_period('Q') # Extract quarter information

quarterly_revenue = df.groupby('quarter')['revenue'].sum()
quarterly_revenue.plot(kind='bar', color='skyblue')
plt.xlabel('Quarter')
plt.ylabel('Total Revenue')
plt.title('Total Revenue Generated in Each Quarter')
plt.xticks(rotation=0)  # Rotate x-axis labels for better readability
plt.grid(axis='y')  # Add horizontal gridlines
plt.show()

# %% [markdown]
# Ex.5

# %%
import numpy as np
x = np.linspace(-10, 10, 100)
y = x**2

plt.plot(x, y, label='y = x^2', color='pink')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of y = x^2')

plt.legend()
plt.grid(True)
plt.show()

# %%
products = ['A', 'B', 'C', 'D']
sales_values = [15, 30, 45, 20]

plt.bar(products, sales_values, color='darkblue')

plt.xlabel('Products')
plt.ylabel('Sales')
plt.title('Weekly Sales of Different Products')

plt.grid(axis='y')
plt.show()

# %%
fruits = ['Apples', 'Bananas', 'Cherries', 'Dates']
percentages = [40, 30, 20, 10]
colors = ['gold', 'lightgreen', 'lightcoral', 'lightskyblue']

plt.pie(percentages, labels=fruits, colors=colors, autopct='%1.1f%%', startangle=140)
plt.legend(title='Fruits', loc='best')
plt.title('Favorite Fruits')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.tight_layout()
plt.show()
