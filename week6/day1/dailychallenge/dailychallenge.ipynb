# %% [markdown]
# Generate data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Generate temperature data
temperature_data = np.random.uniform(-5, 35, size=(10, 12))  # 10 cities, 12 months

# Creating a DataFrame with city names as index and months as columns
cities = [f"City_{i}" for i in range(1, 11)]
months = [
    "Jan", "Feb", "Mar", "Apr", "May", "Jun",
    "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"
]
temperature_df = pd.DataFrame(temperature_data, index=cities, columns=months)

print(temperature_df)
# Out:
#                Jan        Feb        Mar        Apr        May        Jun  \
# City_1   -3.282737   4.013677   0.937707  16.436587  33.966290  19.065126
# City_2   30.174960   0.909855  -1.873921   3.703963  15.407221  -2.611776
# City_3   23.040854   0.264527  26.952782  30.933636  28.629415  -0.361679
# City_4   27.242636  27.481118  31.214273  10.357310  12.220614   4.998649
# City_5    3.102471   1.600072   5.281675   4.557295  -1.679256  32.885130
# City_6   32.562365  11.269928  11.515463  19.706189   3.298032  21.439343
# City_7   27.570427   3.190595  27.162448   1.911046  16.803668  33.021177
# City_8   14.656930  22.663863  21.219793   8.385381  25.318746  23.817566
# City_9   32.441541  31.204852   8.869128  25.960795  12.998961  -0.367544
# City_10  28.364339   6.382930  21.757035  33.997749   0.902939   6.819764
#
#                Jul        Aug        Sep        Oct        Nov        Dec
# City_1    2.202114   6.546891   9.909015  10.818723  33.758029   4.178120
# ...

# %% [markdown]
# Data analysis

# %%
# Annual average temperature for each city
annual_avg_temp = temperature_df.mean(axis=1)

# Find the city with the highest and lowest average temperature
city_highest_temp = annual_avg_temp.idxmax()
city_lowest_temp = annual_avg_temp.idxmin()

print("Annual average temperature for each city:")
print(annual_avg_temp)
print(f"\nCity with the highest average temperature: {city_highest_temp}")
print(f"City with the lowest average temperature: {city_lowest_temp}")
# Out:
# Annual average temperature for each city:
# City_1     11.545795
# City_2     10.193217
# City_3     15.148313
# City_4     14.726233
# City_5     12.926402
# City_6     17.026749
# City_7     15.644057
# City_8     14.506021
# City_9     20.375535
# City_10    11.307899
# dtype: float64
#
# City with the highest average temperature: City_9
# City with the lowest average temperature: City_2

# %% [markdown]
# Data visuaization

# %%
plt.figure(figsize=(10, 6))

for city in temperature_df.index:
    if city == city_highest_temp:
        plt.plot(months, temperature_df.loc[city], label=city, linestyle='--', linewidth=2)
    elif city == city_lowest_temp:
        plt.plot(months, temperature_df.loc[city], label=city, linestyle='-.', linewidth=2)
    else:
        plt.plot(months, temperature_df.loc[city], label=city, linestyle='-', linewidth=1)

plt.title('Monthly Temperature Trends for Cities')
plt.xlabel('Months')
plt.ylabel('Temperature (°C)')
plt.legend()
plt.grid(True)
plt.xticks(months)  # Set x-axis ticks as months
plt.tight_layout()

plt.show()
