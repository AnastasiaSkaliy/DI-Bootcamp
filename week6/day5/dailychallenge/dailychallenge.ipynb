# %% [markdown]
# Data Loading And Exploration:

# %%
import pandas as pd
df = pd.read_csv(r'/train.csv')
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %% [markdown]
# battery_power: The energy a battery can store, measured in mAh (milliampere-hour).
# blue: Represents if Bluetooth is present (1) or not (0).
# clock_speed: The speed at which the microprocessor executes instructions, measured in GHz (gigahertz).
# dual_sim: Indicates whether the phone supports dual SIM cards (1) or not (0).
# fc: Stands for Front Camera megapixels.
# four_g: Indicates if the phone has 4G capability (1) or not (0).
# int_memory: Internal Memory of the phone in gigabytes (GB).
# m_dep: Mobile Depth in cm.
# mobile_wt: Weight of mobile phone.
# n_cores: Number of cores of the processor.
# pc: Primary Camera megapixels.
# px_height: Pixel Resolution Height.
# px_width: Pixel Resolution Width.
# ram: Random Access Memory of the device in megabytes (MB).
# sc_h: Screen Height of the mobile in cm.
# sc_w: Screen Width of the mobile in cm.
# talk_time: Longest time that a single battery charge will last when you are on a call, measured in hours.
# three_g: Indicates if the phone has 3G capability (1) or not (0).
# touch_screen: Indicates if the phone has a touch screen (1) or not (0).
# wifi: Indicates if the phone supports Wi-Fi (1) or not (0).
# price_range: Represents the price category of the phone (target variable).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %% [markdown]
# Data Cleaning And Preprocessing:

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %% [markdown]
# No missing values detected

# %%
df.drop_duplicates(inplace = True)

# %%
df.dtypes
# Out:
# battery_power      int64
# blue               int64
# clock_speed      float64
# dual_sim           int64
# fc                 int64
# four_g             int64
# int_memory         int64
# m_dep            float64
# mobile_wt          int64
# n_cores            int64
# pc                 int64
# px_height          int64
# px_width           int64
# ram                int64
# sc_h               int64
# sc_w               int64
# talk_time          int64
# three_g            int64
# touch_screen       int64
# wifi               int64
# price_range        int64
# dtype: object

# %% [markdown]
# We will check maybe 'price range' we'll convert to categorical type of data. And the sme all boolean (1 and 0) columns - maybe we'll convert to categorical type.

# %% [markdown]
# Statistical Analysis With NumPy And SciPy:

# %% [markdown]
# Central Tendency Measures:

# %%
df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %% [markdown]
# Analysis of Variability:

# %%
# Calculate range for each column
range_values = df.max() - df.min()

# Calculate variance and standard deviation for each column
variance_values = df.var()
std_deviation = df.std()

print(f'Range for each column: {range_values}')
print(f'Variance for each column: {variance_values}')
print(f'Standard deviation for each column: {std_deviation}')
# Out:
# Range for each column: battery_power    1497.0
# blue                1.0
# clock_speed         2.5
# dual_sim            1.0
# fc                 19.0
# four_g              1.0
# int_memory         62.0
# m_dep               0.9
# mobile_wt         120.0
# n_cores             7.0
# pc                 20.0
# px_height        1960.0
# px_width         1498.0
# ram              3742.0
# sc_h               14.0
# sc_w               18.0
# talk_time          18.0
# three_g             1.0
# touch_screen        1.0
# wifi                1.0
# price_range         3.0
# dtype: float64
# Variance for each column: battery_power    1.930884e+05
# blue             2.501001e-01
# clock_speed      6.658629e-01
# dual_sim         2.500348e-01
# fc               1.884813e+01
# four_g           2.496626e-01
# int_memory       3.292670e+02
# m_dep            8.318353e-02
# mobile_wt        1.253136e+03
# n_cores          5.234197e+00
# pc               3.677592e+01
# px_height        1.969414e+05
# ...

# %%
#Evaluation of Distribution Shapes:

from scipy.stats import skew, kurtosis

# Calculate skewness and kurtosis for each column
skewness = df.apply(skew)
kurtosis_values = df.apply(kurtosis)
print(f'Skewness for each column: {skewness}')
print(f'Kurtosis for each column: {kurtosis_values}')
# Out:
# Skewness for each column: battery_power    0.031875
# blue             0.020001
# clock_speed      0.177951
# dual_sim        -0.038007
# fc               1.019046
# four_g          -0.086080
# int_memory       0.057846
# m_dep            0.089015
# mobile_wt        0.006553
# n_cores          0.003625
# pc               0.017293
# px_height        0.665771
# px_width         0.014776
# ram              0.006623
# sc_h            -0.098810
# sc_w             0.633312
# talk_time        0.009505
# three_g         -1.227220
# touch_screen    -0.012000
# wifi            -0.028003
# price_range      0.000000
# dtype: float64
# Kurtosis for each column: battery_power   -1.224084
# blue            -1.999600
# clock_speed     -1.323109
# dual_sim        -1.998555
# fc               0.273386
# four_g          -1.992590
# int_memory      -1.216034
# m_dep           -1.274164
# mobile_wt       -1.210351
# n_cores         -1.229676
# pc              -1.171571
# px_height       -0.318075
# ...

# %% [markdown]
# Hypothesis Testing:

# %%
df['price_range'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       1
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 1995    0
# 1996    2
# 1997    3
# 1998    0
# 1999    3
# Name: price_range, Length: 2000, dtype: int64>

# %%
from scipy.stats import f_oneway

# Assuming 'price_range' has values 0, 1, 2, and 3
grouped_data = [df[df['price_range'] == i]['battery_power'] for i in range(4)]

# Perform ANOVA test between price ranges for a specific feature
f_statistic, p_value = f_oneway(*grouped_data)
alpha = 0.05
print(f"ANOVA test: F-statistic = {f_statistic:.2f}, p-value = {p_value:.4f}")

if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference in the mean battery power among different price ranges.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference in the mean battery power among different price ranges.")
# Out:
# ANOVA test: F-statistic = 31.60, p-value = 0.0000
# Reject the null hypothesis: There is a significant difference in the mean battery power among different price ranges.

# %% [markdown]
# Feature-Target Correlations:

# %%
from scipy.stats import pearsonr

# Calculate Pearson correlation coefficient between each feature and 'price_range'
correlations = {}
for col in df.columns[:-1]:
    corr, p_val = pearsonr(df[col], df['price_range'])
    correlations[col] = corr
for feature, corr in correlations.items():
    print(f"Pearson correlation between {feature} and 'price_range': {corr}")
# Out:
# Pearson correlation between battery_power and 'price_range': 0.20072261211373096
# Pearson correlation between blue and 'price_range': 0.020572854061418466
# Pearson correlation between clock_speed and 'price_range': -0.00660569088173205
# Pearson correlation between dual_sim and 'price_range': 0.017444479237224753
# Pearson correlation between fc and 'price_range': 0.02199820777690427
# Pearson correlation between four_g and 'price_range': 0.014771711417239396
# Pearson correlation between int_memory and 'price_range': 0.04443495938898741
# Pearson correlation between m_dep and 'price_range': 0.0008530365050864221
# Pearson correlation between mobile_wt and 'price_range': -0.030302171314386412
# Pearson correlation between n_cores and 'price_range': 0.004399274799457295
# Pearson correlation between pc and 'price_range': 0.03359930021353949
# Pearson correlation between px_height and 'price_range': 0.14885755500042172
# ...

# %% [markdown]
# Data Visualization With Matplotlib:

# %%
import matplotlib.pyplot as plt

columns_for_histograms = ['battery_power', 'ram', 'talk_time']
fig, axs = plt.subplots(len(columns_for_histograms), 1, figsize=(8, 6*len(columns_for_histograms)))

for i, col in enumerate(columns_for_histograms):
    axs[i].hist(df[col], bins=20, color='lightgreen', edgecolor='black')
    axs[i].set_xlabel(col)
    axs[i].set_ylabel('Frequency')
    axs[i].set_title(f'Histogram of {col}')

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
columns_for_scatter = ['battery_power', 'ram', 'talk_time']

for col in columns_for_scatter:
    plt.figure(figsize=(8, 6))
    sns.scatterplot(data=df, x=col, y='price_range', alpha=0.5)
    plt.xlabel(col)
    plt.ylabel('Price Range')
    plt.title(f'Scatter plot of {col} against Price Range')
    plt.show()

# %% [markdown]
# Employ heatmaps for correlation visualization.

# %%
correlation_matrix = df.corr()


plt.figure(figsize=(14, 12))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)

plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# We can observe that nearly all the variables have minimal influence one on another.
# However, a notable strong positive relationship of 0.92 is detected between 'ram' (Random Access Memory of the device) and the 'price_range'. Additionally, a considerable positive relationship of 0.64 exists between 'pc' (Primary Camera) and 'fc' (Front Camera megapixels).
#
# Another noteworthy relationship is seen between '3G' and '4G', showing a positive correlation of 0.58.
# All other characteristics showed no correlation.

# %% [markdown]
# From the statistical tests and visualizations conducted:
#
# Key Determinants in Mobile Price Classification:
# RAM (Random Access Memory): The strongest determinant appears to be RAM, showing a highly significant positive relationship with the price range. Higher RAM tends to correspond to higher price ranges.
# Primary Camera (PC) and Front Camera (FC): There's a notable positive relationship between these camera features. This suggests that devices with higher megapixels in the primary camera also tend to have higher megapixels in the front camera, potentially affecting price categorization.
# 3G and 4G Connectivity: The positive correlation between 3G and 4G might indicate that devices supporting both these connectivity options tend to belong to higher price categories.
# Unexpected or Significant Findings:
# Lack of Correlation: Most features exhibited no significant correlation with the price range. This could suggest that factors other than those included in this dataset contribute more significantly to pricing decisions.
# Strong RAM Influence: The exceptionally strong correlation between RAM and price range might indicate that in this dataset, RAM plays a crucial role in determining a mobile device's price classification, overshadowing other features.
# Camera Megapixels Relationship: While it's not unexpected to see a positive correlation between primary and front camera megapixels, the strength of this relationship emphasizes the importance of camera specifications in pricing.
# Conclusions:
# RAM Dominance: Manufacturers might prioritize enhancing RAM capacities to influence pricing strategies, given its prominent impact on price categorization observed in this dataset.
# Camera Features: Considering the notable relationship between primary and front camera specifications, emphasizing improvements in camera capabilities could influence price positioning in the market.
# Connectivity Options: Devices supporting both 3G and 4G may tend to command higher price segments, indicating the market's value for multiple connectivity options.
