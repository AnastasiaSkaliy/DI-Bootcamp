# %%
print('Anastasia')
# Out:
# Anastasia

# %%
def fact(number: int):
  result = 1
  while number > 1:
    result = result * number
    number = number - 1
  return result
fact(3)
# Out:
# 6

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots() # create a figure and axes
ax.plot([1,2,3,4],[1,4,2,3]) # plot some data on the axes

# %%
#create a line plot for the function y = x^2 ranging from 0 to 10 , x = 0,1,2...10 y = 0,1,4,100
x = list(range(0,11))
y = [i ** 2 for i in x]
fig, ax = plt.subplots()
ax.plot(x,y)

# %%
y
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
import numpy as np
x = np.linspace(0,10,100)
y = np.sin(x)

fig,ax = plt.subplots()
ax.plot(x,y)
plt.show()

# %%
x = np.random.rand(50)
y = np.random.rand(50)

fix, ax = plt.subplots()
ax.scatter(x,y)
plt.show()

# %%
ages = [15,24,37,18,59,70,40]
incomes = [1,14,22,6,12,28,11]

# %%
fig,ax = plt.subplots()
ax.scatter(ages,incomes)
ax.set(title = 'Incomes by Age', xlabel = 'Age', ylabel = 'Incomes/Month')
plt.show()

# %%
#Exercice
x = [1,1.5,2,2.5,3,3.5]
y = [2,3,1,4,1,3]
fig,ax = plt.subplots()
ax.scatter(ages,incomes)
ax.set(title = 'Relationship between Spending and Income', xlabel = 'Income', ylabel = 'Spending')
plt.show()

# %%
data = np.random.randn(400)

fig, ax = plt.subplots()
ax.hist(data, bins=50)
plt.show()

# %%
my_data = [1,2,3,4,1,2,5,4,1,2,3,4,5,3,2,1]
fig, ax = plt.subplots()
ax.hist(data, bins=10)
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])
fig.savefig('my_figure.png')  # save the figure to file

# %% [markdown]
# # Новый раздел
