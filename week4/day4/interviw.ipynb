# %%
import pandas as pd
df = pd.read_excel(r'/analyst_live_exercise_data.xlsx')
df.head()
# Out:
#    Unnamed: 0                                           sentence   code  \
# 0           0  pt transferred to [**hospital unit name 4**] c...    J80
# 1           1  chb d/t hypothyroidism--pt with recent hx of n...   E039
# 2           2  the patient is a 67-year-old female with a his...  I4891
# 3           3  rca, htn, gerd, left knee replacement, bipolar...   F319
# 4           4  chronic obstructive pulmonary disease diabetes...   E119
#
#    correct
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True

# %%
df.sentence
# Out:
# 0        pt transferred to [**hospital unit name 4**] c...
# 1        chb d/t hypothyroidism--pt with recent hx of n...
# 2        the patient is a 67-year-old female with a his...
# 3        rca, htn, gerd, left knee replacement, bipolar...
# 4        chronic obstructive pulmonary disease diabetes...
#                                ...
# 81022    # encephalopathy following improvement of pati...
# 81023     secondary progressive ms, sx onset [**8-/2167...
# 81024    major depressive disorder, recurrent, without ...
# 81025                               h/o major depression 3
# 81026    during extensive history taking, the psychiatr...
# Name: sentence, Length: 81027, dtype: object

# %%
vc = df.correct.value_counts()
vc
# Out:
# True     65316
# False    15711
# Name: correct, dtype: int64

# %%
df.info() #quick check that you have no
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81027 entries, 0 to 81026
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  81027 non-null  int64
#  1   sentence    81027 non-null  object
#  2   code        81027 non-null  object
#  3   correct     81027 non-null  bool
# dtypes: bool(1), int64(1), object(2)
# memory usage: 1.9+ MB

# %%
t = df.nunique()
t
# Out:
# Unnamed: 0    64477
# sentence      77524
# code             50
# correct           2
# dtype: int64

# %%
len(df) - t['sentence']
# Out:
# 3503

# %%
ct=pd.crosstab(df.code,df.correct)
ct.head()
# Out:
# correct  False  True
# code
# A419       558   1964
# B182       332   1725
# C787        28     53
# C7931      266   1103
# D696       374   1892

# %%
ct['%correct'] = ct[True]*100 / (ct[True]+ct[False])
ct.sort_volues(by='%correct')
