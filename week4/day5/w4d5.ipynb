# %%
import pandas as pd

# %%
df = pd.read_csv(r'/content/sample_data/california_housing_train.csv')
df.head(10) # 10 first rows
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
# 7    -114.59     34.83                41.0        812.0           168.0
# 8    -114.59     33.61                34.0       4789.0          1175.0
# 9    -114.60     34.83                46.0       1497.0           309.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# ...

# %%
#all streets with population over 800
df[df['population']>800]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 6        -114.58     33.61                25.0       2907.0           680.0
# 8        -114.59     33.61                34.0       4789.0          1175.0
# 10       -114.60     33.62                16.0       3741.0           801.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(df['population'])
plt.show()

# %%
df['median_house_value'].max()
# Out:
# 500001.0

# %%
df[df['median_house_value']>400000]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 215      -116.43     33.75                24.0       2596.0           438.0
# 220      -116.44     33.74                 5.0        846.0           249.0
# 260      -116.55     33.84                28.0       2992.0           562.0
# 521      -117.00     33.29                17.0       2073.0           313.0
# 650      -117.04     32.90                 6.0       6525.0           826.0
# ...          ...       ...                 ...          ...             ...
# 16434    -122.57     37.96                52.0       3458.0           468.0
# 16439    -122.58     38.15                 9.0       1302.0           177.0
# 16482    -122.62     37.85                30.0        833.0           164.0
# 16512    -122.64     37.96                29.0        377.0            58.0
# 16560    -122.68     38.07                26.0       1445.0           244.0
#
# ...

# %%
df['total_rooms'].min()
# Out:
# 2.0

# %%
expen_small = df[(df['median_house_value']>300000) & (df['total_rooms'] < 100)]
expen_small
result = df.drop(expen_small)
result
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-b3531a87b01a> in <cell line: 3>()
#       1 expen_small = df[(df['median_house_value']>300000) & (df['total_rooms'] < 100)]
#       2 expen_small
# ----> 3 result = df.drop(expen_small)
#       4 result
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
# ...

# %%
drop = df.drop(result)
drop
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-5e4b597e5974> in <cell line: 1>()
# ----> 1 drop = df.drop(result)
#       2 drop
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...
